# %%
import requests as req
import json
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
appkey = "bgy96hxcecgj62e84apgdejn"
brkcik = "0001067983"

# %%
query_url = "http://edgaronline.api.mashery.com/v2/ownerships/currentownerholdings?ciks=%s&appkey=%s" % (brkcik, appkey)
print(query_url)
# Out:
# http://edgaronline.api.mashery.com/v2/ownerships/currentownerholdings?ciks=0001067983&appkey=bgy96hxcecgj62e84apgdejn

# %%
sec_data = req.get(query_url).json()
print(json.dumps(sec_data, indent=4, sort_keys=True))
# Out:
# {
#     "result": {
#         "rows": [
#             {
#                 "rownum": 1,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1344226
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "QSR"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "RESTAURANT BRANDS INTL INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "226 WYECROFT ROAD"
#                     },
#                     {
#                         "field": "city",
#                         "value": "OAKVILLE"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "L6K 3X7"
#                     },
#                     {
#                         "field": "country",
#                         "value": "CANADA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "905"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "8456511"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 235617365.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "4/26/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 60.57
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 8438225.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 511103288.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.003181239751598202
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.035813255954203545
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 2,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1338737
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "AXTA"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "AXALTA COATING SYS LTD"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "TWO COMMERCE SQUARE"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "2001 MARKET STREET, SUITE 3600"
#                     },
#                     {
#                         "field": "city",
#                         "value": "PHILADELPHIA"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Pennsylvania"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "19103"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "855"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "5471461"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 243164757.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/3/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 29.2
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 23324000.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 681060800.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.004239099495316244
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.09591850516396996
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 3,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1273357
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "GHC"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "GRAHAM HLDGS CO"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "1300 NORTH 17TH STREET"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "SUITE 1700"
#                     },
#                     {
#                         "field": "city",
#                         "value": "ARLINGTON"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Virginia"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "22209"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "703"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "3456300"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 4628229.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/2/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 574.7
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 107575.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 61823353.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.000384804623171761
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.023243231914410457
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 4,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1271363
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "SIRI"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "SIRIUS XM HLDGS INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "1290 AVENUE OF THE AMERICAS"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "11TH FLOOR"
#                     },
#                     {
#                         "field": "city",
#                         "value": "NEW YORK"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10104"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "212"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "5845100"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 4613015656.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "7/27/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 5.49
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 137915729.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": -34409624.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": -0.19967824467476936
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 757157352.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": -188908835.76
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.004712744220102205
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.029897086696555535
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 5,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1222557
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "LBTYK"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "LIBERTY GLOBAL PLC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "SHS CL C"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 3
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 595562538.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/8/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 32.39
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 7346968.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 237968294.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.001481176533720143
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.012336182233141065
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 6,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1222555
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "LBTYA"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "LIBERTY GLOBAL PLC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "SHS CL A"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 3
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "161 HAMMERSMITH ROAD"
#                     },
#                     {
#                         "field": "city",
#                         "value": "HAMMERSMITH"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "W6 8BS"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED KINGDOM"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "303"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "2206600"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 225487900.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/8/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 33.4
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 20180897.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 674041960.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.004195412410254667
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.08949880237476157
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 7,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1178708
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "MDLZ"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "MONDELEZ INTL INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "CL A"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "THREE PARKWAY NORTH"
#                     },
#                     {
#                         "field": "city",
#                         "value": "DEERFIELD"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Illinois"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "60015"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "847"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "9434000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 1507639931.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/2/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 42.94
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 578000.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 24819320.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.000154481900714433
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.000383380665446171
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 8,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 954658
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "BK"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "BANK NEW YORK MELLON CORP"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "225 LIBERTY STREET"
#                     },
#                     {
#                         "field": "city",
#                         "value": "NEW YORK"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10286"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "212"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "4951784"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 1033156201.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/3/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 52.1
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 50229588.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 17217529.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.5215527150245309
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 2616961535.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 897033260.9
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.01628864900502352
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.04861761266242451
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 9,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 687090
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "MCO"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "MOODYS CORP"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "7 WORLD TRADE CENTER"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "AT 250 GREENWICH STREET"
#                     },
#                     {
#                         "field": "city",
#                         "value": "NEW YORK"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10007"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "212"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "5530300"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 191000000.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "7/24/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 130.49
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 24669778.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 3219159331.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.020036884659027032
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.12916114136125653
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 10,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 680188
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "VZ"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "VERIZON COMMUNICATIONS INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "1095 AVENUE OF THE AMERICAS"
#                     },
#                     {
#                         "field": "city",
#                         "value": "NEW YORK"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10036"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "212"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "3951000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 4079407956.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/3/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 47.69
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 928.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 44256.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 2.7546085058e-07
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 2.27483990326e-07
# ...
#                         "value": 18621674.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 1.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 462934816.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 462934815.64
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.002881426658045681
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.09799999620034175
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 23,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 991780
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "V"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "VISA INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM CL A"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "P.O. BOX 8999"
#                     },
#                     {
#                         "field": "city",
#                         "value": "SAN FRANCISCO"
#                     },
#                     {
#                         "field": "state",
#                         "value": "California"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "94128-8999"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "650"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "4323200"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 1829370035.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "7/20/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 102.51
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 10562460.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 1082757775.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.006739365909111549
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.005773823664931737
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 24,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 865999
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "MA"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "MASTERCARD INCORPORATED"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "CL A"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "2000 PURCHASE STREET"
#                     },
#                     {
#                         "field": "city",
#                         "value": "PURCHASE"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10577"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "914"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "2492000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 1049179397.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "7/27/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 131.14
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 4934756.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 647143902.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.004027991903755413
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.004703443485556741
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 25,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "8/21/2017 2:13 PM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "3/31/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 739770
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "SNY"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "SANOFI"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "SPONSORED ADR"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "54 RUE LA BOETIE"
#                     },
#                     {
#                         "field": "city",
#                         "value": "PARIS"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "75008"
#                     },
#                     {
#                         "field": "country",
#                         "value": "FRANCE"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "3"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "315"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "3774400"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 2524905966.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "8/8/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 48.19
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "8/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 3905875.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 188224116.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.001171555836339349
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.001546938797957595
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             }
#         ],
#         "totalrows": 48
#     }
# }

# %%
currentreportdate = None
sec_json = []
for row in sec_data["result"]["rows"]:
    ticker = None
    company = None
    shares = None
    marketvalue = None
    for value in row["values"]:
        if not(currentreportdate) and value["field"] == "currentreportdate":
            currentreportdate = value["value"]
        if value["field"] == "ticker":
            ticker = value["value"]
        if value["field"] == "companyname":
            company = value["value"]
        if value["field"] == "sharesheld":
            shares = value["value"]
        if value["field"] == "marketvalue":
            marketvalue = value["value"]
    if ticker and company and shares and marketvalue:
        #print({'ticker': ticker, 'company': company, 'shares': float(shares), 'marketvalue': float(marketvalue)})
        sec_json.append({'ticker': ticker, 'company': company, 'shares': float(shares), 'marketvalue': float(marketvalue)})
   
#print(sec_json)
sec_df = pd.DataFrame(sec_json)
print(currentreportdate)
sec_df.head()
# Out:
# 6/30/2017 12:00 AM
#                       company  marketvalue       shares ticker
# 0  RESTAURANT BRANDS INTL INC  511103288.0    8438225.0    QSR
# 1      AXALTA COATING SYS LTD  681060800.0   23324000.0   AXTA
# 2             GRAHAM HLDGS CO   61823353.0     107575.0    GHC
# 3         SIRIUS XM HLDGS INC  757157352.0  137915729.0   SIRI
# 4          LIBERTY GLOBAL PLC  237968294.0    7346968.0  LBTYK

# %%
secsum_df = sec_df.groupby(['ticker','company'], as_index=False).sum()
secsum_df.head()
# Out:
#   ticker                         company   marketvalue       shares
# 0   AAPL                       APPLE INC  2.050523e+10  130191960.0
# 1   AXTA          AXALTA COATING SYS LTD  6.810608e+08   23324000.0
# 2     BK       BANK NEW YORK MELLON CORP  2.616962e+09   50229588.0
# 3   CHTR  CHARTER COMMUNICATIONS INC NEW  3.711009e+09    9443491.0
# 4   COST            COSTCO WHSL CORP NEW  6.806847e+08    4333363.0

# %%
for idx, row in secsum_df.iterrows():
    time.sleep(5)
    ticker_url = 'http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "%s"&appkey=%s' % (row["ticker"], appkey)
    print(ticker_url)
    ticker_data = req.get(ticker_url).json()
    try:
        for row in ticker_data["result"]["rows"]:
            sector = None
            sectorid = None
            industry = None
            industryid = None
            for value in row["values"]:
                if value["field"] == "sector":
                    sector = value["value"]
                if value["field"] == "sectorid":
                    sectorid = value["value"]
                if value["field"] == "industry":
                    industry = value["value"]
                if value["field"] == "industryid":
                    industryid = value["value"]
            if sector and sectorid and industry and industryid:
                secsum_df.set_value(idx,"sector", sector)
                secsum_df.set_value(idx,"sectorID", int(sectorid))
                secsum_df.set_value(idx,"industry", industry)
                secsum_df.set_value(idx,"industryID", int(industryid))
    except:
        print("error grabbing data for %s" % (row["ticker"]))
# Out:
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "AAPL"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "AXTA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "BK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "CHTR"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "COST"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "GHC"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "GS"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "IBM"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "KHC"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LBTYA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LBTYK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LILAK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LSXMK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MCO"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MDLZ"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MTB"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "PG"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "QSR"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "SIRI"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "SNY"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "STOR"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "V"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "VZ"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "WFC"&appkey=bgy96hxcecgj62e84apgdejn

# %%
secsum_df.head()
# Out:
#   ticker                         company   marketvalue       shares  \
# 0   AAPL                       APPLE INC  2.050523e+10  130191960.0
# 1   AXTA          AXALTA COATING SYS LTD  6.810608e+08   23324000.0
# 2     BK       BANK NEW YORK MELLON CORP  2.616962e+09   50229588.0
# 3   CHTR  CHARTER COMMUNICATIONS INC NEW  3.711009e+09    9443491.0
# 4   COST            COSTCO WHSL CORP NEW  6.806847e+08    4333363.0
#
#                sector  sectorID                                industry  \
# 0          Technology      27.0                       Computer Hardware
# 1     Basic Materials      21.0                     Commodity Chemicals
# 2          Financials      25.0  Investment Management & Fund Operators
# 3  Consumer Cyclicals      23.0                            Broadcasting
# 4  Consumer Cyclicals      23.0                         Discount Stores
#
#    industryID
# 0       169.0
# 1        15.0
# 2       208.0
# 3        94.0
# 4       101.0

# %%
file_date = currentreportdate.split(" ")[0]
file_prefix = file_date.replace("/","_") 
output_file = file_prefix + "_brk.csv"
chart_output_fig = file_prefix + "_chart_brk.png"

#print(output_file)
secsum_df.to_csv(output_file,index=False)

# %%
shr_yaxis = secsum_df.groupby(["industry"])["shares"].sum()
mval_yaxis = secsum_df.groupby(["industry"])["marketvalue"].sum()
xaxis = secsum_df["industry"].unique()

# %%
fig, ax1 = plt.subplots(1, 1)
fig.set_size_inches(10, 7.5)
ax1.bar(range(len(xaxis)), shr_yaxis, color="blue", label="Shares")
tick_locations = [value + 0.1 for value in range(len(xaxis))]
ax1.set_xticks(tick_locations)
ax1.set_xticklabels(xaxis, rotation=90)

ax1.set_title("Berkshire Hathaway 13F Industry Group Allocation (%s)" % file_date, y = 1.08)
ax1.set_xlabel("Industry Group")

ax1.set_ylabel("Shares", color="blue")
ax1.tick_params('y', colors="blue")

ax1b = ax1.twinx()
ax1b.plot(range(len(xaxis)), mval_yaxis, "o-", lw=2, color="red", label = 'Market Value')
ax1b.set_ylabel("Market Value", color="red")
ax1b.tick_params('y', colors="red")

sns.set()
plt.tight_layout()
plt.savefig(chart_output_fig)
plt.show()
