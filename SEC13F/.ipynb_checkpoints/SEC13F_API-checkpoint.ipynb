# %%
import requests as req
import json
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
appkey = "bgy96hxcecgj62e84apgdejn"
brkcik = "0001067983"

# %%
query_url = "http://edgaronline.api.mashery.com/v2/ownerships/currentownerholdings?ciks=%s&appkey=%s" % (brkcik, appkey)
print(query_url)
# Out:
# http://edgaronline.api.mashery.com/v2/ownerships/currentownerholdings?ciks=0001067983&appkey=bgy96hxcecgj62e84apgdejn

# %%
sec_data = req.get(query_url).json()
print(json.dumps(sec_data, indent=4, sort_keys=True))
# Out:
# {
#     "result": {
#         "rows": [
#             {
#                 "rownum": 1,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1372929
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "LILAK"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "LIBERTY GLOBAL PLC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "LILAC SHS CL C"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 120819385.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "11/1/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 21.4
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 1284020.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 27478028.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.000145007016337895
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.010627599205210322
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 2,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1083589
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "UAL"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "UNITED CONTL HLDGS INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "JENNIFER L. KRAFT - WHQLD"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "233 SOUTH WACKER DRIVE"
#                     },
#                     {
#                         "field": "city",
#                         "value": "CHICAGO"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Illinois"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "60606"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "312"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "9978000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 296252435.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/19/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 63.13
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 28211563.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 1780995972.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.00939866980299787
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.09522812192244091
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 3,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 947097
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "DAL"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "DELTA AIR LINES INC DEL"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM NEW"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "HARTSFIELD-JACKSON ATLANTA INTL AIRPORT"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "1030 DELTA BOULEVARD"
#                     },
#                     {
#                         "field": "city",
#                         "value": "ATLANTA"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Georgia"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "30354-1989"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "404"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "7152600"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 712973139.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/11/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 55.25
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 53110395.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 2934349324.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.015485144726046585
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.07449143887032188
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 4,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 702378
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "USB"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "US BANCORP DEL"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM NEW"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "U.S. BANCORP"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "800 NICOLLET MALL"
#                     },
#                     {
#                         "field": "city",
#                         "value": "MINNEAPOLIS"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Minnesota"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "55402-7020"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "651"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "4663000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 1659491166.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "11/3/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 54.15
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 85063167.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 4606170493.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.02430767738986156
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.051258583801343356
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 5,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 688679
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "DVA"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "DAVITA INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "2000 16TH STREET"
#                     },
#                     {
#                         "field": "city",
#                         "value": "DENVER"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Colorado"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "80202"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "310"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "5362668"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 183300000.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 69.03
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 38565570.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 2662181297.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.014048859941059767
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.21039590834697217
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 6,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 548521
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "VRSN"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "VERISIGN INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "12061 BLUEMONT WAY"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "ATTN: GENERAL COUNSEL"
#                     },
#                     {
#                         "field": "city",
#                         "value": "RESTON"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Virginia"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "20190"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "703"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "9483200"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 98570102.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/26/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 114.14
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 12952745.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 1478426314.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.007801949567435207
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.13140642788418744
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             },
#             {
#                 "rownum": 7,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 544685
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "TMK"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "TORCHMARK CORP"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "3700 SOUTH STONEBRIDGE DRIVE"
#                     },
#                     {
#                         "field": "city",
#                         "value": "MCKINNEY"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Texas"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "75070"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "972"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "5694000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 115446832.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "11/7/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 88.86
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 6353727.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 564592181.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.002979465179033772
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.05503595802438303
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 8,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 483440
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "KO"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "COCA COLA CO"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "ONE COCA COLA PLAZA"
#                     },
#                     {
#                         "field": "city",
#                         "value": "ATLANTA"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Georgia"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "30313"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "404"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "6762121"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 4260667316.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/26/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 46.03
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 400000000.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 18412000000.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.0971637842720493
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.09388200728507666
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 9,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 471029
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "AXP"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "AMERICAN EXPRESS CO"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "200 VESEY STREET"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "50TH FLOOR"
#                     },
#                     {
#                         "field": "city",
#                         "value": "NEW YORK"
#                     },
#                     {
#                         "field": "state",
#                         "value": "New York"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "10285"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "212"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "6402000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 867996250.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/24/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 97.15
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 151610700.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 14728979505.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.07772775294217117
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.1746674596808454
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 10,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 1417259
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "CHTR"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "CHARTER COMMUNICATIONS INC NEW"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "CL A"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "400 ATLANTIC STREET"
#                     },
#                     {
#                         "field": "city",
#                         "value": "STAMFORD"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Connecticut"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "06901"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "203"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "9057800"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 248610434.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/26/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 328.68
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 8489391.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": -954100.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": -0.10103255247450334
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 2790293034.0
#                     },
#                     {
# ...
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.019463004760530443
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.1290935531135531
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 23,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 546981
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "UPS"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "UNITED PARCEL SERVICE INC"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "CL B"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "55 GLENLAKE PARKWAY NE"
#                     },
#                     {
#                         "field": "city",
#                         "value": "ATLANTA"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Georgia"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "30328"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "404"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "8286000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 687057463.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "11/2/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 116.84
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 59400.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 6940296.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 3.6625321710198e-05
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 8.6455650653488e-05
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 24,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 546196
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "USG"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "U S G CORP"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM NEW"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 2
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "550 WEST ADAMS STREET"
#                     },
#                     {
#                         "field": "street2",
#                         "value": "DEPARTMENT 188"
#                     },
#                     {
#                         "field": "city",
#                         "value": "CHICAGO"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Illinois"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "60661"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "312"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "6064000"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 141474530.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/26/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 36.54
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 39002016.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 1425133665.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.007520713664180697
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.2756822447121754
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 1
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NYSE"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 1
#                     }
#                 ]
#             },
#             {
#                 "rownum": 25,
#                 "values": [
#                     {
#                         "field": "querydate",
#                         "value": "12/15/2017 10:26 AM"
#                     },
#                     {
#                         "field": "filerid",
#                         "value": 54239
#                     },
#                     {
#                         "field": "cik",
#                         "value": "0001067983"
#                     },
#                     {
#                         "field": "currentreportdate",
#                         "value": "9/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "priorreportdate",
#                         "value": "6/30/2017 12:00 AM"
#                     },
#                     {
#                         "field": "ownername",
#                         "value": "BERKSHIRE HATHAWAY INC"
#                     },
#                     {
#                         "field": "issueid",
#                         "value": 485985
#                     },
#                     {
#                         "field": "ticker",
#                         "value": "COST"
#                     },
#                     {
#                         "field": "companyname",
#                         "value": "COSTCO WHSL CORP NEW"
#                     },
#                     {
#                         "field": "issuetitle",
#                         "value": "COM"
#                     },
#                     {
#                         "field": "exchangeid",
#                         "value": 474
#                     },
#                     {
#                         "field": "exchange",
#                         "value": "Other OTC"
#                     },
#                     {
#                         "field": "street1",
#                         "value": "999 LAKE DRIVE"
#                     },
#                     {
#                         "field": "city",
#                         "value": "ISSAQUAH"
#                     },
#                     {
#                         "field": "state",
#                         "value": "Washington"
#                     },
#                     {
#                         "field": "zip",
#                         "value": "98027-"
#                     },
#                     {
#                         "field": "country",
#                         "value": "UNITED STATES OF AMERICA"
#                     },
#                     {
#                         "field": "phonecountrycode",
#                         "value": "1"
#                     },
#                     {
#                         "field": "phoneareacode",
#                         "value": "425"
#                     },
#                     {
#                         "field": "phonenumber",
#                         "value": "3138100"
#                     },
#                     {
#                         "field": "sharesout",
#                         "value": 436989606.0
#                     },
#                     {
#                         "field": "sharesoutdate",
#                         "value": "10/18/2017 12:00 AM"
#                     },
#                     {
#                         "field": "price",
#                         "value": 186.53
#                     },
#                     {
#                         "field": "pricedate",
#                         "value": "12/14/2017 12:00 AM"
#                     },
#                     {
#                         "field": "sharesheld",
#                         "value": 4333363.0
#                     },
#                     {
#                         "field": "sharesheldchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "sharesheldpercentchange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "marketvalue",
#                         "value": 808302200.0
#                     },
#                     {
#                         "field": "marketvaluechange",
#                         "value": 0.0
#                     },
#                     {
#                         "field": "portfoliopercent",
#                         "value": 0.004265571398404457
#                     },
#                     {
#                         "field": "sharesoutpercent",
#                         "value": 0.009916398331909066
#                     },
#                     {
#                         "field": "marketoperator",
#                         "value": "NASDAQ"
#                     },
#                     {
#                         "field": "marketoperatorid",
#                         "value": 2
#                     },
#                     {
#                         "field": "markettier",
#                         "value": "NASDAQ Global Select Market"
#                     },
#                     {
#                         "field": "markettierid",
#                         "value": 4
#                     }
#                 ]
#             }
#         ],
#         "totalrows": 48
#     }
# }

# %%
currentreportdate = None
sec_json = []
for row in sec_data["result"]["rows"]:
    ticker = None
    company = None
    shares = None
    marketvalue = None
    for value in row["values"]:
        if not(currentreportdate) and value["field"] == "currentreportdate":
            currentreportdate = value["value"]
        if value["field"] == "ticker":
            ticker = value["value"]
        if value["field"] == "companyname":
            company = value["value"]
        if value["field"] == "sharesheld":
            shares = value["value"]
        if value["field"] == "marketvalue":
            marketvalue = value["value"]
    #print('ticker', ticker, 'company', company, 'shares', shares, 'marketvalue', marketvalue)
    if ticker and company and shares and marketvalue:
        #print({'ticker': ticker, 'company': company, 'shares': float(shares), 'marketvalue': float(marketvalue)})
        sec_json.append({'ticker': ticker, 'company': company, 'shares': float(shares), 'marketvalue': float(marketvalue)})
   
#print(sec_json)
sec_df = pd.DataFrame(sec_json)
print(currentreportdate)
sec_df
# Out:
# 9/30/2017 12:00 AM
#                            company   marketvalue       shares ticker
# 0               LIBERTY GLOBAL PLC  2.747803e+07    1284020.0  LILAK
# 1           UNITED CONTL HLDGS INC  1.780996e+09   28211563.0    UAL
# 2          DELTA AIR LINES INC DEL  2.934349e+09   53110395.0    DAL
# 3                   US BANCORP DEL  4.606170e+09   85063167.0    USB
# 4                       DAVITA INC  2.662181e+09   38565570.0    DVA
# 5                     VERISIGN INC  1.478426e+09   12952745.0   VRSN
# 6                   TORCHMARK CORP  5.645922e+08    6353727.0    TMK
# 7                     COCA COLA CO  1.841200e+10  400000000.0     KO
# 8              AMERICAN EXPRESS CO  1.472898e+10  151610700.0    AXP
# 9   CHARTER COMMUNICATIONS INC NEW  2.790293e+09    8489391.0   CHTR
# 10                  KRAFT HEINZ CO  2.571864e+10  325634818.0    KHC
# 11              LIBERTY GLOBAL PLC  5.880374e+07    2714854.0   LILA
# 12                  STORE CAP CORP  4.823014e+08   18621674.0   STOR
# 13          AXALTA COATING SYS LTD  7.347060e+08   23324000.0   AXTA
# 14                  SYNCHRONY FINL  7.695030e+08   20803000.0    SYF
# 15              LIBERTY GLOBAL PLC  2.309152e+08    7346968.0  LBTYK
# 16              LIBERTY GLOBAL PLC  6.524484e+08   20180897.0  LBTYA
# 17                     PHILLIPS 66  8.032679e+09   80689892.0    PSX
# 18         MASTERCARD INCORPORATED  7.497375e+08    4934756.0     MA
# 19                          SANOFI  1.683042e+08    3905875.0    SNY
# 20                 MONSANTO CO NEW  1.045738e+09    8873469.0    MON
# 21                     MOODYS CORP  3.688132e+09   24669778.0    MCO
# 22       UNITED PARCEL SERVICE INC  6.940296e+06      59400.0    UPS
# 23                      U S G CORP  1.425134e+09   39002016.0    USG
# 24            COSTCO WHSL CORP NEW  8.083022e+08    4333363.0   COST

# %%
secsum_df = sec_df.groupby(['ticker','company'], as_index=False).sum()
secsum_df
# Out:
#    ticker                         company   marketvalue       shares
# 0     AXP             AMERICAN EXPRESS CO  1.472898e+10  151610700.0
# 1    AXTA          AXALTA COATING SYS LTD  7.347060e+08   23324000.0
# 2    CHTR  CHARTER COMMUNICATIONS INC NEW  2.790293e+09    8489391.0
# 3    COST            COSTCO WHSL CORP NEW  8.083022e+08    4333363.0
# 4     DAL         DELTA AIR LINES INC DEL  2.934349e+09   53110395.0
# 5     DVA                      DAVITA INC  2.662181e+09   38565570.0
# 6     KHC                  KRAFT HEINZ CO  2.571864e+10  325634818.0
# 7      KO                    COCA COLA CO  1.841200e+10  400000000.0
# 8   LBTYA              LIBERTY GLOBAL PLC  6.524484e+08   20180897.0
# 9   LBTYK              LIBERTY GLOBAL PLC  2.309152e+08    7346968.0
# 10   LILA              LIBERTY GLOBAL PLC  5.880374e+07    2714854.0
# 11  LILAK              LIBERTY GLOBAL PLC  2.747803e+07    1284020.0
# 12     MA         MASTERCARD INCORPORATED  7.497375e+08    4934756.0
# 13    MCO                     MOODYS CORP  3.688132e+09   24669778.0
# 14    MON                 MONSANTO CO NEW  1.045738e+09    8873469.0
# 15    PSX                     PHILLIPS 66  8.032679e+09   80689892.0
# 16    SNY                          SANOFI  1.683042e+08    3905875.0
# 17   STOR                  STORE CAP CORP  4.823014e+08   18621674.0
# 18    SYF                  SYNCHRONY FINL  7.695030e+08   20803000.0
# 19    TMK                  TORCHMARK CORP  5.645922e+08    6353727.0
# 20    UAL          UNITED CONTL HLDGS INC  1.780996e+09   28211563.0
# 21    UPS       UNITED PARCEL SERVICE INC  6.940296e+06      59400.0
# 22    USB                  US BANCORP DEL  4.606170e+09   85063167.0
# 23    USG                      U S G CORP  1.425134e+09   39002016.0
# 24   VRSN                    VERISIGN INC  1.478426e+09   12952745.0

# %%
for idx, row in secsum_df.iterrows():
    time.sleep(5)
    ticker_url = 'http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "%s"&appkey=%s' % (row["ticker"], appkey)
    print(ticker_url)
    ticker_data = req.get(ticker_url).json()
    try:
        for row in ticker_data["result"]["rows"]:
            sector = None
            sectorid = None
            industry = None
            industryid = None
            for value in row["values"]:
                if value["field"] == "sector":
                    sector = value["value"]
                if value["field"] == "sectorid":
                    sectorid = value["value"]
                if value["field"] == "industry":
                    industry = value["value"]
                if value["field"] == "industryid":
                    industryid = value["value"]
            if sector and sectorid and industry and industryid:
                secsum_df.set_value(idx,"sector", sector)
                secsum_df.set_value(idx,"sectorID", int(sectorid))
                secsum_df.set_value(idx,"industry", industry)
                secsum_df.set_value(idx,"industryID", int(industryid))
    except:
        print("error grabbing data for %s" % (row["ticker"]))
# Out:
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "AXP"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "AXTA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "CHTR"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "COST"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "DAL"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "DVA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "KHC"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "KO"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LBTYA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LBTYK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LILA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "LILAK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MA"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MCO"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "MON"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "PSX"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "SNY"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "STOR"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "SYF"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "TMK"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "UAL"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "UPS"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "USB"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "USG"&appkey=bgy96hxcecgj62e84apgdejn
# http://edgaronline.api.mashery.com/v2/ownerships/issues?filter=ticker eq "VRSN"&appkey=bgy96hxcecgj62e84apgdejn

# %%
secsum_df
# Out:
#    ticker                         company   marketvalue       shares  \
# 0     AXP             AMERICAN EXPRESS CO  1.472898e+10  151610700.0
# 1    AXTA          AXALTA COATING SYS LTD  7.347060e+08   23324000.0
# 2    CHTR  CHARTER COMMUNICATIONS INC NEW  2.790293e+09    8489391.0
# 3    COST            COSTCO WHSL CORP NEW  8.083022e+08    4333363.0
# 4     DAL         DELTA AIR LINES INC DEL  2.934349e+09   53110395.0
# 5     DVA                      DAVITA INC  2.662181e+09   38565570.0
# 6     KHC                  KRAFT HEINZ CO  2.571864e+10  325634818.0
# 7      KO                    COCA COLA CO  1.841200e+10  400000000.0
# 8   LBTYA              LIBERTY GLOBAL PLC  6.524484e+08   20180897.0
# 9   LBTYK              LIBERTY GLOBAL PLC  2.309152e+08    7346968.0
# 10   LILA              LIBERTY GLOBAL PLC  5.880374e+07    2714854.0
# 11  LILAK              LIBERTY GLOBAL PLC  2.747803e+07    1284020.0
# 12     MA         MASTERCARD INCORPORATED  7.497375e+08    4934756.0
# 13    MCO                     MOODYS CORP  3.688132e+09   24669778.0
# 14    MON                 MONSANTO CO NEW  1.045738e+09    8873469.0
# 15    PSX                     PHILLIPS 66  8.032679e+09   80689892.0
# 16    SNY                          SANOFI  1.683042e+08    3905875.0
# 17   STOR                  STORE CAP CORP  4.823014e+08   18621674.0
# 18    SYF                  SYNCHRONY FINL  7.695030e+08   20803000.0
# 19    TMK                  TORCHMARK CORP  5.645922e+08    6353727.0
# 20    UAL          UNITED CONTL HLDGS INC  1.780996e+09   28211563.0
# 21    UPS       UNITED PARCEL SERVICE INC  6.940296e+06      59400.0
# 22    USB                  US BANCORP DEL  4.606170e+09   85063167.0
# 23    USG                      U S G CORP  1.425134e+09   39002016.0
# 24   VRSN                    VERISIGN INC  1.478426e+09   12952745.0
#
#                     sector  sectorID                           industry  \
# 0               Financials      25.0                   Consumer Lending
# 1          Basic Materials      21.0                Commodity Chemicals
# 2       Consumer Cyclicals      23.0                       Broadcasting
# 3       Consumer Cyclicals      23.0                    Discount Stores
# 4              Industrials      22.0                           Airlines
# 5               Healthcare      26.0   Healthcare Facilities & Services
# 6   Consumer Non-Cyclicals      24.0                    Food Processing
# 7   Consumer Non-Cyclicals      24.0            Non-Alcoholic Beverages
# 8       Consumer Cyclicals      23.0                       Broadcasting
# 9       Consumer Cyclicals      23.0                       Broadcasting
# 10      Consumer Cyclicals      23.0                       Broadcasting
# 11      Consumer Cyclicals      23.0                       Broadcasting
# 12              Technology      27.0                  Internet Services
# 13             Industrials      22.0  Professional Information Services
# 14         Basic Materials      21.0             Agricultural Chemicals
# 15                  Energy      20.0   Oil & Gas Refining and Marketing
# 16              Healthcare      26.0                    Pharmaceuticals
# 17              Financials      25.0                   Commercial REITs
# 18              Financials      25.0                   Consumer Lending
# 19              Financials      25.0            Life & Health Insurance
# 20             Industrials      22.0                           Airlines
# 21             Industrials      22.0            Air Freight & Logistics
# 22              Financials      25.0                              Banks
# 23         Basic Materials      21.0             Construction Materials
# 24              Technology      27.0           IT Services & Consulting
#
#     industryID
# 0        129.0
# 1         15.0
# 2         94.0
# 3        101.0
# 4         60.0
# 5        154.0
# 6        114.0
# 7        111.0
# 8         94.0
# 9         94.0
# 10        94.0
# 11        94.0
# 12       291.0
# 13       243.0
# 14        16.0
# 15         8.0
# 16       277.0
# 17       216.0
# 18       129.0
# 19       139.0
# 20        60.0
# 21        58.0
# 22       128.0
# 23        26.0
# 24       290.0

# %%
file_date = currentreportdate.split(" ")[0]
file_prefix = file_date.replace("/","_") 
output_file = file_prefix + "_brk.csv"
chart_output_fig = file_prefix + "_chart_brk.png"

#print(output_file)
secsum_df.to_csv(output_file,index=False)

# %%
shr_yaxis = secsum_df.groupby(["industry"])["shares"].sum()
mval_yaxis = secsum_df.groupby(["industry"])["marketvalue"].sum()
xaxis = secsum_df["industry"].unique()

# %%
fig, ax1 = plt.subplots(1, 1)
fig.set_size_inches(10, 7.5)
ax1.bar(range(len(xaxis)), shr_yaxis, color="blue", label="Shares")
tick_locations = [value + 0.1 for value in range(len(xaxis))]
ax1.set_xticks(tick_locations)
ax1.set_xticklabels(xaxis, rotation=90)

ax1.set_title("Berkshire Hathaway 13F Industry Group Allocation (%s)" % file_date, y = 1.08)
ax1.set_xlabel("Industry Group")

ax1.set_ylabel("Shares", color="blue")
ax1.tick_params('y', colors="blue")

ax1b = ax1.twinx()
ax1b.plot(range(len(xaxis)), mval_yaxis, "o-", lw=2, color="red", label = 'Market Value')
ax1b.set_ylabel("Market Value", color="red")
ax1b.tick_params('y', colors="red")

sns.set()
plt.tight_layout()
plt.savefig(chart_output_fig)
plt.show()
